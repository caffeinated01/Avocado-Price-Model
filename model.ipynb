# %%
import pandas as pd

df = pd.read_csv("datasets/avocado.csv", index_col=0)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df["type"].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
df["type"].astype("category").cat.codes
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 7     1
# 8     1
# 9     1
# 10    1
# 11    1
# Length: 18249, dtype: int8

# %%
df["type"] = df["type"].astype("category").cat.codes
df["region"] = df["region"].astype("category").cat.codes
df = df.drop("Date", axis=1)
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region
# 0     8603.62       93.25          0.0     0  2015       0
# 1     9408.07       97.49          0.0     0  2015       0
# 2     8042.21      103.14          0.0     0  2015       0
# 3     5677.40      133.76          0.0     0  2015       0
# 4     5986.26      197.69          0.0     0  2015       0

# %%
import sklearn
from sklearn import svm, preprocessing

df = sklearn.utils.shuffle(df)

X = df.drop("AveragePrice", axis=1).values
X = preprocessing.scale(X)
Y = df["AveragePrice"].values

test_size = 1000

X_train = X[:-test_size]
Y_train = Y[:-test_size]

X_test = X[test_size:]
Y_test = Y[test_size:]

clf = svm.SVR(kernel="linear")
clf.fit(X_train, Y_train)
# Out:
# SVR(kernel='linear')

# %%
clf.score(X_test, Y_test)
# Out:
# 0.4054974219488947

# %%
for X,Y in zip(X_test,Y_test):
    print(f"Predicted Price: {clf.predict([X])[0]}, Actual Price: {Y}")
# Out:
# Predicted Price: 1.0281165791047324, Actual Price: 1.11
# Predicted Price: 1.1693191722890965, Actual Price: 1.72
# Predicted Price: 1.1657999573506683, Actual Price: 1.03
# Predicted Price: 1.1504472453777528, Actual Price: 1.62
# Predicted Price: 1.6168122011918737, Actual Price: 1.34
# Predicted Price: 1.659687502773311, Actual Price: 1.67
# Predicted Price: 1.5959153830058597, Actual Price: 1.81
# Predicted Price: 1.1703763268559797, Actual Price: 1.16
# Predicted Price: 1.6945612975154143, Actual Price: 1.31
# Predicted Price: 1.2349917011075204, Actual Price: 1.32
# Predicted Price: 1.6291492891875354, Actual Price: 2.25
# Predicted Price: 1.5976875383472333, Actual Price: 1.68
# Predicted Price: 1.596403873907946, Actual Price: 2.01
# Predicted Price: 1.6586503319657613, Actual Price: 1.08
# Predicted Price: 1.0981661070557818, Actual Price: 1.09
# Predicted Price: 1.1631292604139594, Actual Price: 1.43
# Predicted Price: 1.1415001648376615, Actual Price: 0.99
# ...

# %%
clf = svm.SVR(kernel="rbf")
clf.fit(X_train, Y_train)
# Out:
# SVR()

# %%
clf.score(X_test, Y_test)
# Out:
# 0.5291612580109092

# %%
for X,Y in zip(X_test,Y_test):
    print(f"Predicted Price: {clf.predict([X])[0]}, Actual Price: {Y}")
# Out:
# Predicted Price: 1.0453346046240561, Actual Price: 1.11
# Predicted Price: 1.327604501676449, Actual Price: 1.72
# Predicted Price: 1.1028076731509688, Actual Price: 1.03
# Predicted Price: 1.1880512743525302, Actual Price: 1.62
# Predicted Price: 1.3087973498273002, Actual Price: 1.34
# Predicted Price: 1.7637172662817882, Actual Price: 1.67
# Predicted Price: 1.7202070625510266, Actual Price: 1.81
# Predicted Price: 1.0515133749340266, Actual Price: 1.16
# Predicted Price: 1.5309606510742277, Actual Price: 1.31
# Predicted Price: 1.2343038738746377, Actual Price: 1.32
# Predicted Price: 1.5071419595622741, Actual Price: 2.25
# Predicted Price: 1.643983197176895, Actual Price: 1.68
# Predicted Price: 1.7114691961105954, Actual Price: 2.01
# Predicted Price: 1.7358204814357596, Actual Price: 1.08
# Predicted Price: 1.0833744634284899, Actual Price: 1.09
# Predicted Price: 1.3149505418079384, Actual Price: 1.43
# Predicted Price: 0.9592010854945492, Actual Price: 0.99
# ...
